# %%
import pandas as pd
from pymongo import MongoClient

connection_string = "mongodb+srv://Fernando:gefpez-cukvi6-viwZik@cluster0.azbeyxo.mongodb.net/"#"mongodb://localhost:27017"

# Establish a connection to the MongoDB server
client = MongoClient(connection_string)

# Access the database and collection
db = client['secondCA']
collection = db['dataset']

# %%
# Find documents where the date field is "date"
query = {'date': 'date'}

# Iterate documents
documents = collection.find(query)
for doc in documents:
    print(doc)

# %%
# Delete the documents that match the query
result = collection.delete_many(query)
print(f"Deleted {result.deleted_count} documents.")
# Out:
# Deleted 0 documents.

# %%
# Using the method find() to extract everything
cursor = collection.find()
# Convert the cursor to a list of dictionaries
data = list(cursor)

# %%
# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(data)

# Close the connection
client.close()

# %%
# Display the first 10 rows of the DataFrame
df.head(5)
# Out:
#                         _id   index         ids       date      flag  \
# 0  664ae330dd9d2cd697d98afc  800008  1467822489 2009-04-07  NO_QUERY
# 1  664ae330dd9d2cd697d98af3      20  1467813985 2009-04-07  NO_QUERY
# 2  664ae330dd9d2cd697d98b01  800018  1467822936 2009-04-07  NO_QUERY
# 3  664ae330dd9d2cd697d98b04  800034  1467823824 2009-04-07  NO_QUERY
# 4  664ae330dd9d2cd697d98b07  800044  1467824185 2009-04-07  NO_QUERY
#
#               user                                               text  \
# 0       emmasaur28  @tommcfly ah, congrats mr fletcher for finally...
# 1           quanvu  @alydesigns i was out most of the day so didn'...
# 2      adamjackson  Catching Up on Emails, RSS and Random BACN. Th...
# 3  AngryBadgerGirl    @wisdomous you're welcome. glad you enjoyed it.
# 4        Eric_John  Practicing lines/mannerisms/voices for upcomin...
#
#             timestamp  sentiment_score
# 0 2009-04-07 05:22:49           0.5267
# 1 2009-04-07 05:20:37           0.0000
# ...

# %%
df.columns
# Out:
# Index(['_id', 'index', 'ids', 'date', 'flag', 'user', 'text', 'timestamp',
#        'sentiment_score'],
#       dtype='object')

# %%
#check datatype of each column
df.dtypes
# Out:
# _id                        object
# index                       int64
# ids                         int64
# date               datetime64[ns]
# flag                       object
# user                       object
# text                       object
# timestamp          datetime64[ns]
# sentiment_score           float64
# dtype: object

# %%
df.describe()
# Out:
#               index           ids                           date  \
# count  1.597983e+06  1.597983e+06                        1597983
# mean   7.996111e+05  1.998870e+09  2009-05-31 02:51:36.415919104
# min    0.000000e+00  1.467810e+09            2009-04-07 00:00:00
# 25%    3.995965e+05  1.956927e+09            2009-05-29 00:00:00
# 50%    7.992200e+05  2.002113e+09            2009-06-02 00:00:00
# 75%    1.199610e+06  2.177096e+09            2009-06-15 00:00:00
# max    1.599999e+06  2.329206e+09            2009-06-25 00:00:00
# std    4.618817e+05  1.935930e+08                            NaN
#
#                            timestamp  sentiment_score
# count                        1597983     1.597983e+06
# mean   2009-05-31 14:32:20.345970688     1.410423e-01
# min              2009-04-07 05:19:45    -9.985000e-01
# 25%              2009-05-29 06:02:59    -7.720000e-02
# 50%              2009-06-02 10:11:02     0.000000e+00
# 75%              2009-06-15 12:26:23     5.267000e-01
# ...

# %%
# Print all unique values in the "date" column
unique_dates = df['date'].unique()
unique_dates
# Out:
# <DatetimeArray>
# ['2009-04-07 00:00:00', '2009-04-18 00:00:00', '2009-04-19 00:00:00',
#  '2009-04-20 00:00:00', '2009-04-21 00:00:00', '2009-05-02 00:00:00',
#  '2009-05-03 00:00:00', '2009-05-04 00:00:00', '2009-05-10 00:00:00',
#  '2009-05-11 00:00:00', '2009-05-12 00:00:00', '2009-05-14 00:00:00',
#  '2009-05-17 00:00:00', '2009-05-18 00:00:00', '2009-05-22 00:00:00',
#  '2009-05-24 00:00:00', '2009-05-25 00:00:00', '2009-05-27 00:00:00',
#  '2009-05-29 00:00:00', '2009-05-30 00:00:00', '2009-05-31 00:00:00',
#  '2009-06-01 00:00:00', '2009-06-02 00:00:00', '2009-06-03 00:00:00',
#  '2009-06-04 00:00:00', '2009-06-05 00:00:00', '2009-06-06 00:00:00',
#  '2009-06-07 00:00:00', '2009-06-08 00:00:00', '2009-06-14 00:00:00',
#  '2009-06-15 00:00:00', '2009-06-16 00:00:00', '2009-06-17 00:00:00',
#  '2009-06-18 00:00:00', '2009-06-19 00:00:00', '2009-06-20 00:00:00',
#  '2009-06-21 00:00:00', '2009-06-22 00:00:00', '2009-06-23 00:00:00',
# ...

# %%
print(df.head(5))
# Out:
#                         _id  index         ids       date      flag  \
# 0  664ae330dd9d2cd697d98af3     20  1467813985 2009-04-07  NO_QUERY
# 1  664ae330dd9d2cd697d98af4     22  1467814119 2009-04-07  NO_QUERY
# 2  664ae330dd9d2cd697d98af5     37  1467817374 2009-04-07  NO_QUERY
# 3  664ae330dd9d2cd697d98af6     39  1467818007 2009-04-07  NO_QUERY
# 4  664ae330dd9d2cd697d98af7     45  1467819650 2009-04-07  NO_QUERY
#
#              user                                               text  \
# 0          quanvu  @alydesigns i was out most of the day so didn'...
# 1       cooliodoc    @angry_barista I baked you a cake but I ated it
# 2         ajaxpro  @MissXu sorry! bed time came here (GMT+1)   ht...
# 3  Anthony_Nguyen  Bed. Class 8-12. Work 12-3. Gym 3-5 or 6. Then...
# 4       antzpantz  @Viennah Yay! I'm happy for you with your job!...
#
#             timestamp  sentiment_score
# 0 2009-04-07 05:20:37           0.0000
# 1 2009-04-07 05:20:40           0.0000
# ...

# %%
import matplotlib.pyplot as plt

# Group by date and calculate the average sentiment score
df_daily = df.groupby('date')['sentiment_score'].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df_daily['date'], df_daily['sentiment_score'], marker='o', linestyle='-', color='b')

# Adding title and labels
plt.title('Average Sentiment Score per Day')
plt.xlabel('Date')
plt.ylabel('Sentiment Score')

# Display the plot
plt.grid(True)
plt.show()

# %%
# Aggregate sentiment scores by date
daily_sentiment = df.groupby('date')['sentiment_score'].mean().reset_index()

# %%
# Set date as index
daily_sentiment.set_index('date', inplace=True)

# %%
# Create a complete date range
all_dates = pd.date_range(start=daily_sentiment.index.min(), end=daily_sentiment.index.max(), freq='D')

# %%
# Reindex DataFrame to include all dates
daily_sentiment = daily_sentiment.reindex(all_dates)

# %%
# Interpolate missing values
daily_sentiment['sentiment_score'] = daily_sentiment['sentiment_score'].interpolate(method='time')

# %%
# Ensure the DataFrame is now ready for ARIMA modeling
print(daily_sentiment.head(10))
# Out:
#             sentiment_score
# 2009-04-07         0.817127
# 2009-04-08         0.826395
# 2009-04-09         0.835663
# 2009-04-10         0.844931
# 2009-04-11         0.854199
# 2009-04-12         0.863467
# 2009-04-13         0.872735
# 2009-04-14         0.882003
# 2009-04-15         0.891271
# 2009-04-16         0.900539

# %%
print(daily_sentiment.tail(10))
# Out:
#             sentiment_score
# 2009-06-16         0.726300
# 2009-06-17         0.023985
# 2009-06-18         0.036158
# 2009-06-19         0.049352
# 2009-06-20         0.057763
# 2009-06-21         0.099033
# 2009-06-22         0.011268
# 2009-06-23         0.000000
# 2009-06-24         0.016176
# 2009-06-25         0.025802

# %%
#!pip install pmdarima

# %% [markdown]
# ## ARIMA analysis

# %%
import pmdarima as pm

# Fit ARIMA model
model = pm.auto_arima(daily_sentiment['sentiment_score'], seasonal=False, stepwise=True)
# Out:
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
# Forecast for 1, 3, and 7 days ahead
forecast_1_day = model.predict(n_periods=1)
print("1 day forecast:", forecast_1_day)
# Out:
# 1 day forecast: 2009-06-26   -0.064643
# Freq: D, dtype: float64
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# ...

# %%
forecast_3_days = model.predict(n_periods=3)
print("3 days forecast:", forecast_3_days)
# Out:
# 3 days forecast: 2009-06-26   -0.064643
# 2009-06-27   -0.071226
# 2009-06-28   -0.066642
# Freq: D, dtype: float64
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# ...

# %%
forecast_7_days = model.predict(n_periods=7)
print("7 days forecast:", forecast_7_days)
# Out:
# 7 days forecast: 2009-06-26   -0.064643
# 2009-06-27   -0.071226
# 2009-06-28   -0.066642
# 2009-06-29   -0.066968
# 2009-06-30   -0.075687
# 2009-07-01   -0.080620
# 2009-07-02   -0.079244
# Freq: D, dtype: float64
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %% [markdown]
# ## SARIMA analysis

# %%
# Define seasonal order:
seasonal_order = (1, 1, 1, 7)

# Fit SARIMA model
model_sarima = pm.auto_arima(daily_sentiment['sentiment_score'], 
                      seasonal=True, 
                      m=7,
                      stepwise=True,
                      suppress_warnings=True)
# Out:
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
# Forecast for 1 day in SARIMA
forecast_1_day_sarima = model_sarima.predict(n_periods=1)
print("1 day forecast using SARIMA:", forecast_1_day_sarima)
# Out:
# 1 day forecast using SARIMA: 2009-06-26   -0.051698
# Freq: D, dtype: float64
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# ...

# %%
forecast_3_days_sarima = model_sarima.predict(n_periods=3)
print("3 days forecast using SARIMA:", forecast_3_days_sarima)
# Out:
# 3 days forecast using SARIMA: 2009-06-26   -0.051698
# 2009-06-27   -0.051698
# 2009-06-28   -0.051698
# Freq: D, dtype: float64
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# ...

# %%
forecast_7_days_sarima = model_sarima.predict(n_periods=7)
print("7 days forecast using SARIMA:", forecast_7_days_sarima)
# Out:
# 7 days forecast using SARIMA: 2009-06-26   -0.051698
# 2009-06-27   -0.051698
# 2009-06-28   -0.051698
# 2009-06-29   -0.051698
# 2009-06-30   -0.051698
# 2009-07-01   -0.051698
# 2009-07-02   -0.051698
# Freq: D, dtype: float64
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %% [markdown]
# ## LSTM analysis

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
daily_sentiment['sentiment_score'] = scaler.fit_transform(daily_sentiment['sentiment_score'].values.reshape(-1, 1))

# %%
# Prepare the data for LSTM
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %%
seq_length = 30 

X_lstm, y_lstm = create_sequences(daily_sentiment['sentiment_score'].values, seq_length)

# %%
# Reshape 
X_lstm = X_lstm.reshape((X_lstm.shape[0], X_lstm.shape[1], 1))

# %%
# Build the LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(50, activation='relu', input_shape=(seq_length, 1)))
model_lstm.add(Dense(1))
model_lstm.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model_lstm.fit(X_lstm, y_lstm, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 0s 105ms/step - loss: 0.6550 - val_loss: 0.0370
# Epoch 2/20
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5892 - val_loss: 0.0347
# Epoch 3/20
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5251 - val_loss: 0.0340
# Epoch 4/20
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4618 - val_loss: 0.0351
# Epoch 5/20
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4002 - val_loss: 0.0386
# Epoch 6/20
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3397 - val_loss: 0.0450
# Epoch 7/20
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2808 - val_loss: 0.0555
# Epoch 8/20
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2246 - val_loss: 0.0722
# Epoch 9/20
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1664 - val_loss: 0.0991
# Epoch 10/20
# ...

# %%
# Make forecasts for the next 1, 3, and 7 days
def forecast(model, data, seq_length, n_steps):
    data = data.reshape((1, seq_length, 1))
    forecasts = []
    for _ in range(n_steps):
        forecast = model.predict(data)
        forecasts.append(forecast[0, 0])
        data = np.append(data[:, 1:, :], forecast.reshape((1, 1, 1)), axis=1)
    return forecasts

# %%
# Use the last sequence from the training data as the starting point for the forecast
last_sequence = daily_sentiment['sentiment_score'].values[-seq_length:]
forecasts_1_day = forecast(model_lstm, last_sequence, seq_length, 1)
forecasts_3_days = forecast(model_lstm, last_sequence, seq_length, 3)
forecasts_7_days = forecast(model_lstm, last_sequence, seq_length, 7)

# Inverse transform the forecasts to original scale
forecasts_1_day = scaler.inverse_transform(np.array(forecasts_1_day).reshape(-1, 1))
forecasts_3_days = scaler.inverse_transform(np.array(forecasts_3_days).reshape(-1, 1))
forecasts_7_days = scaler.inverse_transform(np.array(forecasts_7_days).reshape(-1, 1))

print("1 day forecast:", forecasts_1_day)
print("3 days forecast:", forecasts_3_days)
print("7 days forecast:", forecasts_7_days)
# Out:
# ...
# 1/1 [==============================] - 0s 8ms/step
# 1 day forecast: [[0.01374713]]
# 3 days forecast: [[0.01374713]
#  [0.01492115]
#  [0.01620602]]
# 7 days forecast: [[0.01374713]
#  [0.01492115]
#  [0.01620602]
#  [0.01743072]
#  [0.01864529]
#  [0.01983993]
#  [0.02101069]]

# %%
#!pip install dash
# !pip install dash-bootstrap-components
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 kB 2.9 MB/s eta 0:00:00a 0:00:01
# ...

# %% [markdown]
# ## Table of results according to the model:

# %% [markdown]
# | Date       | LSTM Forecast | ARIMA Forecast | SARIMA Forecast |
# |------------|----------------|----------------|------------------|
# | 2009-06-26 | 0.016206       | -0.064643      | -0.051698        |
# | 2009-06-27 | 0.014921       | -0.071226      | -0.051698        |
# | 2009-06-28 | 0.016206       | -0.066642      | -0.051698        |
# | 2009-06-29 | 0.017431       | -0.066968      | -0.051698        |
# | 2009-06-30 | 0.018645       | -0.075687      | -0.051698        |
# | 2009-07-01 | 0.019840       | -0.080620      | -0.051698        |
# | 2009-07-02 | 0.021011       | -0.079244      | -0.051698        |

# %% [markdown]
# ## Dashboard

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output
import plotly.graph_objs as go

# Actual sentiment scores before forecasting since 2009-06-16
dates_before_forecast = pd.date_range(start='2009-06-16', periods=10, freq='D')
sentiment_scores_before_forecast = [0.7263, 0.023985, 0.036158, 0.049352, 0.057763, 0.099033, 0.011268, 0.000000, 0.016176, 0.025802]

# LSTM outputs:
forecasts_1_day = [0.01620602]
forecasts_3_days = [0.01374713, 0.01492115, 0.01620602]
forecasts_7_days = [0.016206023, 0.01492115, 0.01620602, 0.01743072, 0.01864529, 0.01983993, 0.02101069]

# Dates for the forecast periods since 2009-06-26
date_1_day = pd.date_range(start='2009-06-26', periods=1, freq='D')
dates_3_days = pd.date_range(start='2009-06-26', periods=3, freq='D')
dates_7_days = pd.date_range(start='2009-06-26', periods=7, freq='D')

# ARIMA outputs:
arima_forecast_1 = [-0.064643]
arima_forecast_3 = [-0.064643, -0.071226, -0.066642]
arima_forecast_7 = [-0.064643, -0.071226, -0.066642, -0.066968, -0.075687, -0.080620, -0.079244]

# SARIMA outputs:
sarima_forecast_1 = [-0.051698]
sarima_forecast_3 = [-0.051698, -0.051698, -0.051698]
sarima_forecast_7 = [-0.051698, -0.051698, -0.051698, -0.051698, -0.051698, -0.051698, -0.051698]

# Combine historical data and forecasts into DataFrames for each forecast period
df_1_day = pd.DataFrame({
    'Date': list(dates_before_forecast) + list(date_1_day),
    'ARIMA': sentiment_scores_before_forecast + arima_forecast_1,
    'SARIMA': sentiment_scores_before_forecast + sarima_forecast_1,
    'LSTM': sentiment_scores_before_forecast + forecasts_1_day
})

df_3_days = pd.DataFrame({
    'Date': list(dates_before_forecast) + list(dates_3_days),
    'ARIMA': sentiment_scores_before_forecast + arima_forecast_3,
    'SARIMA': sentiment_scores_before_forecast + sarima_forecast_3,
    'LSTM': sentiment_scores_before_forecast + forecasts_3_days
})

df_7_days = pd.DataFrame({
    'Date': list(dates_before_forecast) + list(dates_7_days),
    'ARIMA': sentiment_scores_before_forecast + arima_forecast_7,
    'SARIMA': sentiment_scores_before_forecast + sarima_forecast_7,
    'LSTM': sentiment_scores_before_forecast + forecasts_7_days
})

# Initialize the Dash app
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = html.Div([
    html.H1("Time Series Forecast Comparison"),
    dcc.Dropdown(
        id='forecast-period-dropdown',
        options=[
            {'label': '1 Day', 'value': '1_day'},
            {'label': '3 Days', 'value': '3_days'},
            {'label': '7 Days', 'value': '7_days'}
        ],
        value='1_day',
        multi=False
    ),
    dcc.Graph(id='forecast-graph')
])

@app.callback(
    Output('forecast-graph', 'figure'),
    [Input('forecast-period-dropdown', 'value')]
)
def update_graph(selected_period):
    if selected_period == '1_day':
        df = df_1_day
    elif selected_period == '3_days':
        df = df_3_days
    else:
        df = df_7_days
    
    traces = []
    for model in ['ARIMA', 'SARIMA', 'LSTM']:
        traces.append(go.Scatter(
            x=df['Date'],
            y=df[model],
            mode='lines+markers',
            name=model
        ))

    figure = {
        'data': traces,
        'layout': go.Layout(
            title=f'Forecast Comparison for {selected_period.replace("_", " ").capitalize()}',
            xaxis={'title': 'Date'},
            yaxis={'title': 'Sentiment Score'},
            hovermode='closest'
        )
    }
    return figure

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## hyperparameter tunning technique: Grid Search

# %% [markdown]
# ### hyperparameters in ARIMA

# %%
# Define the parameter grid
param_grid = {
    'p': [0, 1, 2, 3],
    'd': [0, 1],
    'q': [0, 1, 2, 3],
    'P': [0, 1, 2],
    'D': [0, 1],
    'Q': [0, 1, 2],
    'm': [1, 12],
    'seasonal': [True, False],
}

# Convert the grid to a list of parameter combinations
import itertools
grid = list(itertools.product(param_grid['p'], param_grid['d'], param_grid['q'], param_grid['P'], param_grid['D'], param_grid['Q'], param_grid['m'], param_grid['seasonal']))

best_aic = np.inf
best_params = None

# Perform Grid Search
for params in grid:
    p, d, q, P, D, Q, m, seasonal = params
    try:
        model = pm.ARIMA(order=(p, d, q), seasonal_order=(P, D, Q, m) if seasonal else None)
        model.fit(daily_sentiment['sentiment_score'])
        if model.aic() < best_aic:
            best_aic = model.aic()
            best_params = params
    except:
        continue

print(f"Best AIC: {best_aic}")
print(f"Best parameters: {best_params}")
# Out:
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# ...

# %% [markdown]
# ##### ARIMA analysis got:
# Best AIC: -160.50577860861986
#
#
# Best parameters: (0, 1, 2, 1, 0, 0, 12, True)

# %% [markdown]
# ### hyperparameters in SARIMA

# %%
# Define the parameter grid for SARIMA
sarima_param_grid = {
    'sarima_p': [0, 1, 2, 3],
    'sarima_d': [0, 1],
    'sarima_q': [0, 1, 2, 3],
    'sarima_P': [0, 1, 2],
    'sarima_D': [0, 1],
    'sarima_Q': [0, 1, 2],
    'sarima_m': [12],
}

# Convert the grid to a list of parameter combinations
sarima_grid = list(itertools.product(sarima_param_grid['sarima_p'], sarima_param_grid['sarima_d'], sarima_param_grid['sarima_q'],
                                     sarima_param_grid['sarima_P'], sarima_param_grid['sarima_D'], sarima_param_grid['sarima_Q'], sarima_param_grid['sarima_m']))

best_sarima_aic = np.inf
best_sarima_params = None

# Perform Grid Search for SARIMA
for sarima_params in sarima_grid:
    sarima_p, sarima_d, sarima_q, sarima_P, sarima_D, sarima_Q, sarima_m = sarima_params
    try:
        sarima_model = pm.ARIMA(order=(sarima_p, sarima_d, sarima_q), seasonal_order=(sarima_P, sarima_D, sarima_Q, sarima_m))
        sarima_model.fit(daily_sentiment['sentiment_score'])
        if sarima_model.aic() < best_sarima_aic:
            best_sarima_aic = sarima_model.aic()
            best_sarima_params = sarima_params
    except:
        continue

print(f"Best SARIMA AIC: {best_sarima_aic}")
print(f"Best SARIMA parameters: {best_sarima_params}")
# Out:
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# ...

# %% [markdown]
# ##### SARIMA  hyperparameters result:
# Best SARIMA AIC: -160.50577860861986
#
#
# Best SARIMA parameters: (0, 1, 2, 1, 0, 0, 12)

# %% [markdown]
# ## hyperparameter tunning technique: Random Search

# %% [markdown]
# ### hyperparameters in ARIMA

# %%
import random

# Number of random combinations to try
n_iter = 50

best_aic = np.inf
best_params = None

# Perform Random Search
for _ in range(n_iter):
    params = {key: random.choice(value) for key, value in param_grid.items()}
    p, d, q, P, D, Q, m, seasonal = params.values()
    try:
        model = pm.ARIMA(order=(p, d, q), seasonal_order=(P, D, Q, m) if seasonal else None)
        model.fit(daily_sentiment['sentiment_score'])
        if model.aic() < best_aic:
            best_aic = model.aic()
            best_params = params
    except:
        continue

print(f"Best AIC: {best_aic}")
print(f"Best parameters: {best_params}")
# Out:
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# ...

# %% [markdown]
# ##### ARIMA hyperparameter result:
# Best AIC: -158.35872386666114
#
#
# Best parameters: {'p': 2, 'd': 1, 'q': 2, 'P': 2, 'D': 0, 'Q': 0, 'm': 12, 'seasonal': True}

# %% [markdown]
# ### hyperparameters in SARIMA

# %%
import numpy as np
import pmdarima as pm
import random

# Define the parameter grid for SARIMA
sarima_param_grid = {
    'sarima_p': [0, 1, 2, 3],
    'sarima_d': [0, 1],
    'sarima_q': [0, 1, 2, 3],
    'sarima_P': [0, 1, 2],
    'sarima_D': [0, 1],
    'sarima_Q': [0, 1, 2],
    'sarima_m': [12],  # typically 12 for monthly data
}

# Number of random combinations to try
sarima_n_iter = 50

best_sarima_aic = np.inf
best_sarima_params = None

# Perform Random Search for SARIMA
for _ in range(sarima_n_iter):
    sarima_params = {key: random.choice(value) for key, value in sarima_param_grid.items()}
    sarima_p, sarima_d, sarima_q, sarima_P, sarima_D, sarima_Q, sarima_m = sarima_params.values()
    try:
        sarima_model = pm.ARIMA(order=(sarima_p, sarima_d, sarima_q), seasonal_order=(sarima_P, sarima_D, sarima_Q, sarima_m))
        sarima_model.fit(daily_sentiment['sentiment_score'])
        if sarima_model.aic() < best_sarima_aic:
            best_sarima_aic = sarima_model.aic()
            best_sarima_params = sarima_params
    except:
        continue

print(f"Best SARIMA AIC: {best_sarima_aic}")
print(f"Best SARIMA parameters: {best_sarima_params}")
# Out:
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning:
#
# Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#
# /Users/fernandoleniz/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# ...

# %% [markdown]
# #### SARIMA hyperparameter output:
# Best SARIMA AIC: -160.4612871262929
#
#
# Best SARIMA parameters: {'sarima_p': 1, 'sarima_d': 1, 'sarima_q': 0, 'sarima_P': 1, 'sarima_D': 0, 'sarima_Q': 0, 'sarima_m': 12}

# %% [markdown]
# ## Applying hyperparameter tunning technique in LSTM

# %%
# !pip install keras-tuner
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import keras_tuner as kt

# Define the hypermodel
def build_model(hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32),
                   activation=hp.Choice('activation', values=['relu', 'tanh']),
                   input_shape=(seq_length, 1)))
    model.add(Dense(1))
    model.compile(optimizer=hp.Choice('optimizer', values=['adam', 'rmsprop']),
                  loss='mse')
    return model

# Instantiate the tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=5,  # number of different models to try
    executions_per_trial=3,  # number of models to train with each configuration
    directory='my_dir',
    project_name='lstm_tuning'
)

# Run the tuner search
tuner.search(X_lstm, y_lstm, epochs=20, batch_size=32, validation_split=0.2)

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Best units: {best_hps.get('units')}")
print(f"Best activation: {best_hps.get('activation')}")
print(f"Best optimizer: {best_hps.get('optimizer')}")
# Out:
# Trial 5 Complete [00h 00m 06s]
# val_loss: 0.03923839951554934
#
# Best val_loss So Far: 0.03592286258935928
# Total elapsed time: 00h 00m 50s
# Best units: 352
# Best activation: relu
# Best optimizer: adam

# %% [markdown]
# #### LSTM hyperparameters:
#
# - Trial 5 Complete [00h 00m 06s]
# - val_loss: 0.03923839951554934
#
#
#
# - Best val_loss So Far: 0.03592286258935928
# - Total elapsed time: 00h 00m 50s
# - Best units: 352
# - Best activation: relu
# - Best optimizer: adam
